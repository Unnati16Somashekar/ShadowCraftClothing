# %%
from IPython.display import display, HTML

html_code = """
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Shadowcraft Clothing</title>
    <style>
        /* Reset some default styles */
        * {
            margin: 0;
            padding: 0;
            box-sizing: border-box;
            font-family: 'Roboto', sans-serif;
        }

        /* Global styles */
        body {
            font-family: 'Roboto', sans-serif;
            line-height: 1.6;
            background-color: #121212;
            color: #f5f5f5;
            padding: 0;
            margin: 0;
            overflow-x: hidden;
        }

        /* Hero Section */
        .hero {
            position: relative;
            height: 100vh;
            background: linear-gradient(135deg, rgba(30, 30, 30, 0.8), rgba(0, 0, 0, 0.9)), url('https://www.example.com/your-image.jpg');
            background-size: cover;
            background-position: center;
            text-align: center;
            color: #fff;
            display: flex;
            justify-content: center;
            align-items: center;
            flex-direction: column;
            z-index: 1;
        }

        .hero h1 {
            font-size: 5em;
            font-weight: bold;
            text-transform: uppercase;
            margin-bottom: 20px;
            letter-spacing: 5px;
            color: #fff;
        }

        .hero p {
            font-size: 1.5em;
            margin-bottom: 40px;
            max-width: 600px;
            margin: 0 auto;
            opacity: 0.9;
        }

        .cta-button {
            background-color: #f1c40f;
            padding: 15px 35px;
            color: #000;
            text-decoration: none;
            font-size: 1.2em;
            text-transform: uppercase;
            border-radius: 30px;
            letter-spacing: 2px;
            transition: all 0.3s ease;
        }

        .cta-button:hover {
            background-color: #e67e22;
            transform: translateY(-5px);
        }

        /* Features Section */
        .features {
            display: flex;
            justify-content: space-around;
            align-items: center;
            padding: 100px 20px;
            background-color: #1c1c1c;
            gap: 40px;
        }

        .feature {
            background-color: #333;
            padding: 40px;
            border-radius: 20px;
            text-align: center;
            color: #fff;
            flex: 1;
            box-shadow: 0 12px 30px rgba(0, 0, 0, 0.3);
            transition: all 0.3s ease;
        }

        .feature:hover {
            transform: translateY(-10px);
            box-shadow: 0 16px 40px rgba(0, 0, 0, 0.5);
        }

        .feature h3 {
            font-size: 2.5em;
            margin-bottom: 20px;
            font-weight: bold;
        }

        .feature p {
            font-size: 1.2em;
            opacity: 0.8;
        }

        /* Testimonials Section */
        .testimonials {
            padding: 80px 20px;
            background-color: #2c2c2c;
            text-align: center;
        }

        .testimonial {
            margin: 30px auto;
            font-size: 1.4em;
            font-style: italic;
            color: #ddd;
            max-width: 800px;
            text-align: center;
        }

        /* CTA Section */
        .cta {
            padding: 80px 20px;
            background-color: #f1c40f;
            text-align: center;
        }

        .cta h2 {
            font-size: 3em;
            margin-bottom: 20px;
        }

        /* Mobile Styles */
        @media (max-width: 768px) {
            .hero h1 {
                font-size: 2.5em;
            }

            .hero p {
                font-size: 1.2em;
            }

            .features {
                flex-direction: column;
                text-align: center;
            }

            .feature {
                margin-bottom: 40px;
                padding: 30px;
                max-width: 90%;
            }

            .cta-button {
                width: 100%;
                padding: 20px;
            }
        }
    </style>
</head>
<body>

    <!-- Hero Section -->
    <header class="hero">
        <h1>Shadowcraft Clothing</h1>
        <p>Bold fashion for the modern world. Unveil your true style.</p>
        <a href="#cta" class="cta-button">Shop Now</a>
    </header>

    <!-- Features Section -->
    <section id="features" class="features">
        <div class="feature">
            <h3>Premium Quality</h3>
            <p>We use only the finest materials to ensure durability and comfort.</p>
        </div>
        <div class="feature">
            <h3>Unique Designs</h3>
            <p>Our clothes are designed to set you apart, with bold and unique styles.</p>
        </div>
        <div class="feature">
            <h3>Perfect Fit</h3>
            <p>Tailored fits that provide ultimate comfort and style every time.</p>
        </div>
    </section>

    <!-- Testimonials Section -->
    <section id="testimonials" class="testimonials">
        <h2>What Our Customers Say</h2>
        <div class="testimonial">
            <p>"Shadowcraft is my go-to brand! Their clothes are top-notch, and the designs are always on point." - Alex P.</p>
        </div>
        <div class="testimonial">
            <p>"The best fitting clothes I’ve ever worn! Stylish and comfortable, I get compliments every time." - Emma R.</p>
        </div>
        <div class="testimonial">
            <p>"Incredible craftsmanship! Shadowcraft has truly redefined modern fashion." - Liam M.</p>
        </div>
    </section>

    <!-- Call to Action Section -->
    <section id="cta" class="cta">
        <h2>Ready to Upgrade Your Wardrobe?</h2>
        <a href="signup.html" class="cta-button">Shop Now</a>
    </section>

</body>
</html>
"""

# Display the HTML code in the notebook
display(HTML(html_code))
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Shadowcraft Clothing</title>
#     <style>
#         /* Reset some default styles */
#         * {
#             margin: 0;
#             padding: 0;
#             box-sizing: border-box;
#             font-family: 'Roboto', sans-serif;
#         }
#
#         /* Global styles */
#         body {
#             font-family: 'Roboto', sans-serif;
#             line-height: 1.6;
#             background-color: #121212;
#             color: #f5f5f5;
#             padding: 0;
#             margin: 0;
#             overflow-x: hidden;
#         }
#
#         /* Hero Section */
#         .hero {
#             position: relative;
#             height: 100vh;
#             background: linear-gradient(135deg, rgba(30, 30, 30, 0.8), rgba(0, 0, 0, 0.9)), url('https://www.example.com/your-image.jpg');
# ...
